# %% [markdown]
# # Level 2 - Word Prediction using LSTM
#
# Follow the same steps as in Char Prediction (Level 1) but at the word level than at the Char Level.

# %% [markdown]
# ## Importing Packages

# %%
import pandas as pd
import numpy as np
from sklearn.cross_validation import train_test_split
import keras
# Sequence to attain Padding
from keras.preprocessing import sequence
# Importing RNN's LSTM
from keras.layers import LSTM, Dense, Dropout
from keras.layers import Embedding
# Applying Sequential algorithm to model
from keras.models import Sequential
import nltk
from nltk.tokenize import word_tokenize
# Out:
# C:\Users\ab356917\AppData\Local\Continuum\Anaconda3\lib\site-packages\sklearn\cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# Using TensorFlow backend.

# %% [markdown]
# ## Storing the Document

# %%
file = open('AliceinWonderland.txt').read()

# %% [markdown]
# ## Calculation the number of unique words in the document

# %%
# Stores the unique words from the document
words = word_tokenize(file)

# Stores the number of unique words which is the num_classes in outputs
unique_words = list(set(words))
unique_words_count = len(unique_words)
print(unique_words_count)
# Out:
# 3721

# %% [markdown]
# ## convert text words to int

# %%
# Neural Networks accepts only number inputs, so converting text(words) into numbers

## Maps words to numbers
word_to_int = dict(zip(unique_words, [i for i in range(len(unique_words))]))

## Maps numbers back to text
int_to_word = dict(zip([i for i in range(len(unique_words))], unique_words ))

# %%
''' SLIDING FUNCTION: Slides over the input text file words by words'''

def slider(data, slide):
    x = []
    y = []
    for i in range(len(data)-slide):
        x.append([word for word in data[i:i+slide]])
        y.append([data[i+slide]])
    return x,y

# %%
''' WORDS TO INT CONVERSION FUNCTION: Converts words dataset to int dataset '''

def word_data_to_int_data(x,y, word_to_int):
    input_int = []
    output_int = []
    
    for i in range(len(x)):
        input_int.append([word_to_int[word] for word in x[i]])
        output_int.append([word_to_int[word] for word in y[i]])
    return input_int,output_int

# %%
''' INTIALIZATION FUNCTION: Accepts tokenized words, slide, list of unique words from the doc '''

def main(data, slide, char_to_int):
    x, y = slider(data, slide)
    input_int, output_int = word_data_to_int_data(x, y, word_to_int)
    output_int = list(np.array(output_int).flatten())
    input_int = np.array(input_int).reshape(len(input_int),slide,1)
    return input_int,output_int

# %% [markdown]
# ## Initializing

# %%
X,Y = main(words,100,word_to_int)

# %%
''' X=(163716, 100, 1) 

    Number of samples = 163716
    Number of inputs  = 100 (Letter1, Letter2...., Letter100)
               Output = 1 (Letter101th)
'''


X.shape
# Out:
# (38229, 100, 1)

# %%
len(Y)
# Out:
# 38229

# %%
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.01, random_state=1)

# %% [markdown]
# ### One-Hot-Encoding Output Values

# %%
# Total no. of classes = Unique Values in the document, [0,0,0,.....1]
y_train_oneHotEncoded = keras.utils.to_categorical(y_train, num_classes=unique_words_count)
y_test_oneHotEncoded = keras.utils.to_categorical(y_test, num_classes=unique_words_count)

# %%
x_train.shape
# Out:
# (37846, 100, 1)

# %%
y_train_oneHotEncoded.shape
# Out:
# (37846, 3721)

# %% [markdown]
# ## LSTM Model

# %%
model = Sequential()
model.add(LSTM(64,input_shape=(x_train.shape[1], x_train.shape[2]), return_sequences=True))
model.add(LSTM(128))
model.add(Dense(unique_words_count, activation="sigmoid"))
## Compiling Model
model.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy"])

## Fitting Model without weights(Wr or Wht-1)
model.fit(x_train, y_train_oneHotEncoded, batch_size=32, epochs=1, validation_data=(x_test, y_test_oneHotEncoded))
# Out:
# Train on 37846 samples, validate on 383 samples
# Epoch 1/1
# 37846/37846 [==============================] - 178s 5ms/step - loss: 6.3648 - acc: 0.0660 - val_loss: 6.4842 - val_acc: 0.0522

# %%
### Loading Weights
#model.load_weights('weights-improvement-49-1.2575.hdf5', by_name=False)

# %%
### Loading Dropout
#model.add(Dropout(32, input_shape=(x_train.shape[1], x_train.shape[2]))

# %%
predict = model.predict(x_test)

# %%
evaluate = model.evaluate(x_test, y_test_oneHotEncoded)
# Out:
# 383/383 [==============================] - 0s 1ms/step

# %%
accuracy = evaluate[1]
accuracy*100
# Out:
# 5.2219320837573653

# %% [markdown]
# ## Test Input

# %%
test = file[:5000]

# %%
test_x, test_y = main(word_tokenize(test),100,word_to_int)

# %%
test_x.shape
# Out:
# (1016, 100, 1)

# %%
pre = model.predict_classes(test_x)

# %%
output = []
actual = []
for i,j in zip(pre,test_y):
    output.append(int_to_word[i])
    actual.append(int_to_word[j])

# %%
for i, j in zip(output,actual):
    print("predicted : ",i," Actual : ",j)
# Out:
# predicted :  ,  Actual :  Character
# predicted :  ,  Actual :  set
# predicted :  ,  Actual :  encoding
# predicted :  ,  Actual :  :
# predicted :  ,  Actual :  UTF-8
# predicted :  ,  Actual :  ***
# predicted :  ,  Actual :  START
# predicted :  ,  Actual :  OF
# predicted :  ,  Actual :  THIS
# predicted :  ,  Actual :  PROJECT
# predicted :  ,  Actual :  GUTENBERG
# predicted :  ,  Actual :  EBOOK
# predicted :  ,  Actual :  ALICE
# predicted :  ,  Actual :  ’
# predicted :  ,  Actual :  S
# predicted :  ,  Actual :  ADVENTURES
# predicted :  ,  Actual :  IN
# predicted :  ,  Actual :  WONDERLAND
# predicted :  ,  Actual :  ***
# predicted :  ,  Actual :  ALICE
# predicted :  ,  Actual :  ’
# predicted :  ,  Actual :  S
# predicted :  ,  Actual :  ADVENTURES
# predicted :  ,  Actual :  IN
# predicted :  ,  Actual :  WONDERLAND
# predicted :  ,  Actual :  Lewis
# predicted :  ,  Actual :  Carroll
# predicted :  ,  Actual :  THE
# predicted :  ,  Actual :  MILLENNIUM
# predicted :  ,  Actual :  FULCRUM
# predicted :  ,  Actual :  EDITION
# predicted :  ,  Actual :  3.0
# predicted :  ,  Actual :  CHAPTER
# predicted :  ,  Actual :  I
# predicted :  ,  Actual :  .
# predicted :  ,  Actual :  Down
# predicted :  ,  Actual :  the
# predicted :  ,  Actual :  Rabbit-Hole
# predicted :  ,  Actual :  Alice
# predicted :  ,  Actual :  was
# predicted :  ,  Actual :  beginning
# predicted :  ,  Actual :  to
# predicted :  ,  Actual :  get
# predicted :  ,  Actual :  very
# predicted :  ,  Actual :  tired
# predicted :  ,  Actual :  of
# predicted :  ,  Actual :  sitting
# predicted :  ,  Actual :  by
# predicted :  ,  Actual :  her
# predicted :  ,  Actual :  sister
# predicted :  ,  Actual :  on
# predicted :  ,  Actual :  the
# predicted :  ,  Actual :  bank
# predicted :  ,  Actual :  ,
# predicted :  ,  Actual :  and
# predicted :  ,  Actual :  of
# predicted :  ,  Actual :  having
# predicted :  ,  Actual :  nothing
# predicted :  ,  Actual :  to
# predicted :  ,  Actual :  do
# predicted :  ,  Actual :  :
# predicted :  ,  Actual :  once
# predicted :  ,  Actual :  or
# predicted :  ,  Actual :  twice
# predicted :  ,  Actual :  she
# predicted :  ,  Actual :  had
# predicted :  ,  Actual :  peeped
# predicted :  ,  Actual :  into
# predicted :  ,  Actual :  the
# predicted :  ,  Actual :  book
# predicted :  ,  Actual :  her
# predicted :  ,  Actual :  sister
# predicted :  ,  Actual :  was
# predicted :  ,  Actual :  reading
# predicted :  ,  Actual :  ,
# predicted :  ,  Actual :  but
# predicted :  ,  Actual :  it
# predicted :  ,  Actual :  had
# predicted :  ,  Actual :  no
# predicted :  ,  Actual :  pictures
# predicted :  ,  Actual :  or
# predicted :  ,  Actual :  conversations
# predicted :  ,  Actual :  in
# predicted :  ,  Actual :  it
# predicted :  ,  Actual :  ,
# predicted :  ,  Actual :  ‘
# predicted :  ,  Actual :  and
# predicted :  ,  Actual :  what
# predicted :  ,  Actual :  is
# predicted :  ,  Actual :  the
# predicted :  ,  Actual :  use
# predicted :  ,  Actual :  of
# predicted :  ,  Actual :  a
# predicted :  ,  Actual :  book
# predicted :  ,  Actual :  ,
# predicted :  ,  Actual :  ’
# predicted :  ,  Actual :  thought
# predicted :  ,  Actual :  Alice
# predicted :  ,  Actual :  ‘
# predicted :  ,  Actual :  without
# predicted :  ,  Actual :  pictures
# predicted :  ,  Actual :  or
# predicted :  ,  Actual :  conversations
# predicted :  ,  Actual :  ?
# predicted :  ,  Actual :  ’
# predicted :  ,  Actual :  So
# predicted :  ,  Actual :  she
# predicted :  ,  Actual :  was
# predicted :  ,  Actual :  considering
# predicted :  ,  Actual :  in
# predicted :  ,  Actual :  her
# predicted :  ,  Actual :  own
# predicted :  ,  Actual :  mind
# predicted :  ,  Actual :  (
# predicted :  ,  Actual :  as
# predicted :  ,  Actual :  well
# predicted :  ,  Actual :  as
# predicted :  ,  Actual :  she
# predicted :  ,  Actual :  could
# predicted :  ,  Actual :  ,
# predicted :  ,  Actual :  for
# predicted :  ,  Actual :  the
# predicted :  ,  Actual :  hot
# predicted :  ,  Actual :  day
# predicted :  ,  Actual :  made
# predicted :  ,  Actual :  her
# predicted :  ,  Actual :  feel
# predicted :  ,  Actual :  very
# predicted :  ,  Actual :  sleepy
# predicted :  ,  Actual :  and
# predicted :  ,  Actual :  stupid
# predicted :  ,  Actual :  )
# predicted :  ,  Actual :  ,
# predicted :  ,  Actual :  whether
# predicted :  ,  Actual :  the
# predicted :  ,  Actual :  pleasure
# predicted :  ,  Actual :  of
# predicted :  ,  Actual :  making
# predicted :  ,  Actual :  a
# predicted :  ,  Actual :  daisy-chain
# predicted :  ,  Actual :  would
# predicted :  ,  Actual :  be
# predicted :  ,  Actual :  worth
# predicted :  ,  Actual :  the
# predicted :  ,  Actual :  trouble
# predicted :  ,  Actual :  of
# predicted :  ,  Actual :  getting
# predicted :  ,  Actual :  up
# predicted :  ,  Actual :  and
# predicted :  ,  Actual :  picking
# predicted :  ,  Actual :  the
# predicted :  ,  Actual :  daisies
# predicted :  ,  Actual :  ,
# predicted :  ,  Actual :  when
# predicted :  ,  Actual :  suddenly
# predicted :  ,  Actual :  a
# predicted :  ,  Actual :  White
# predicted :  ,  Actual :  Rabbit
# predicted :  ,  Actual :  with
# predicted :  ,  Actual :  pink
# predicted :  ,  Actual :  eyes
# predicted :  ,  Actual :  ran
# predicted :  ,  Actual :  close
# predicted :  ,  Actual :  by
# predicted :  ,  Actual :  her
# predicted :  ,  Actual :  .
# predicted :  ,  Actual :  There
# predicted :  ,  Actual :  was
# predicted :  ,  Actual :  nothing
# predicted :  ,  Actual :  so
# predicted :  ,  Actual :  VERY
# predicted :  ,  Actual :  remarkable
# predicted :  ,  Actual :  in
# predicted :  ,  Actual :  that
# predicted :  ,  Actual :  ;
# predicted :  ,  Actual :  nor
# predicted :  ,  Actual :  did
# predicted :  ,  Actual :  Alice
# predicted :  ,  Actual :  think
# predicted :  ,  Actual :  it
# predicted :  ,  Actual :  so
# predicted :  ,  Actual :  VERY
# predicted :  ,  Actual :  much
# predicted :  ,  Actual :  out
# predicted :  ,  Actual :  of
# predicted :  ,  Actual :  the
# predicted :  ,  Actual :  way
# predicted :  ,  Actual :  to
# predicted :  ,  Actual :  hear
# predicted :  ,  Actual :  the
# predicted :  ,  Actual :  Rabbit
# predicted :  ,  Actual :  say
# predicted :  ,  Actual :  to
# predicted :  ,  Actual :  itself
# predicted :  ,  Actual :  ,
# predicted :  ,  Actual :  ‘
# predicted :  ,  Actual :  Oh
# predicted :  ,  Actual :  dear
# predicted :  ,  Actual :  !
# predicted :  ,  Actual :  Oh
# predicted :  ,  Actual :  dear
# predicted :  ,  Actual :  !
# predicted :  ,  Actual :  I
# predicted :  ,  Actual :  shall
# predicted :  ,  Actual :  be
# predicted :  ,  Actual :  late
# predicted :  ,  Actual :  !
# predicted :  ,  Actual :  ’
# predicted :  ,  Actual :  (
# predicted :  ,  Actual :  when
# predicted :  ,  Actual :  she
# predicted :  ,  Actual :  thought
# predicted :  ,  Actual :  it
# predicted :  ,  Actual :  over
# predicted :  ,  Actual :  afterwards
# predicted :  ,  Actual :  ,
# predicted :  ,  Actual :  it
# predicted :  ,  Actual :  occurred
# predicted :  ,  Actual :  to
# predicted :  ,  Actual :  her
# predicted :  ,  Actual :  that
# predicted :  ,  Actual :  she
# predicted :  ,  Actual :  ought
# predicted :  ,  Actual :  to
# predicted :  ,  Actual :  have
# predicted :  ,  Actual :  wondered
# predicted :  ,  Actual :  at
# predicted :  ,  Actual :  this
# predicted :  ,  Actual :  ,
# predicted :  ,  Actual :  but
# predicted :  ,  Actual :  at
# predicted :  ,  Actual :  the
# predicted :  ,  Actual :  time
# predicted :  ,  Actual :  it
# predicted :  ,  Actual :  all
# predicted :  ,  Actual :  seemed
# predicted :  ,  Actual :  quite
# predicted :  ,  Actual :  natural
# predicted :  ,  Actual :  )
# predicted :  ,  Actual :  ;
# predicted :  ,  Actual :  but
# predicted :  ,  Actual :  when
# predicted :  ,  Actual :  the
# predicted :  ,  Actual :  Rabbit
# predicted :  ,  Actual :  actually
# predicted :  ,  Actual :  TOOK
# predicted :  ,  Actual :  A
# predicted :  ,  Actual :  WATCH
# predicted :  ,  Actual :  OUT
# predicted :  ,  Actual :  OF
# predicted :  ,  Actual :  ITS
# predicted :  ,  Actual :  WAISTCOAT-POCKET
# predicted :  ,  Actual :  ,
# predicted :  ,  Actual :  and
# predicted :  ,  Actual :  looked
# predicted :  ,  Actual :  at
# predicted :  ,  Actual :  it
# predicted :  ,  Actual :  ,
# predicted :  ,  Actual :  and
# predicted :  ,  Actual :  then
# predicted :  ,  Actual :  hurried
# predicted :  ,  Actual :  on
# predicted :  ,  Actual :  ,
# predicted :  ,  Actual :  Alice
# predicted :  ,  Actual :  started
# predicted :  ,  Actual :  to
# predicted :  ,  Actual :  her
# predicted :  ,  Actual :  feet
# predicted :  ,  Actual :  ,
# predicted :  ,  Actual :  for
# predicted :  ,  Actual :  it
# predicted :  ,  Actual :  flashed
# predicted :  ,  Actual :  across
# predicted :  ,  Actual :  her
# predicted :  ,  Actual :  mind
# predicted :  ,  Actual :  that
# predicted :  ,  Actual :  she
# predicted :  ,  Actual :  had
# predicted :  ,  Actual :  never
# predicted :  ,  Actual :  before
# predicted :  ,  Actual :  seen
# predicted :  ,  Actual :  a
# predicted :  ,  Actual :  rabbit
# predicted :  ,  Actual :  with
# predicted :  ,  Actual :  either
# predicted :  ,  Actual :  a
# predicted :  ,  Actual :  waistcoat-pocket
# predicted :  ,  Actual :  ,
# predicted :  ,  Actual :  or
# predicted :  ,  Actual :  a
# predicted :  ,  Actual :  watch
# predicted :  ,  Actual :  to
# predicted :  ,  Actual :  take
# predicted :  ,  Actual :  out
# predicted :  ,  Actual :  of
# predicted :  ,  Actual :  it
# predicted :  ,  Actual :  ,
# predicted :  ,  Actual :  and
# predicted :  ,  Actual :  burning
# predicted :  ,  Actual :  with
# predicted :  ,  Actual :  curiosity
# predicted :  ,  Actual :  ,
# predicted :  ,  Actual :  she
# predicted :  ,  Actual :  ran
# predicted :  ,  Actual :  across
# predicted :  ,  Actual :  the
# predicted :  ,  Actual :  field
# predicted :  ,  Actual :  after
# predicted :  ,  Actual :  it
# predicted :  ,  Actual :  ,
# predicted :  ,  Actual :  and
# predicted :  ,  Actual :  fortunately
# predicted :  ,  Actual :  was
# predicted :  ,  Actual :  just
# predicted :  ,  Actual :  in
# predicted :  ,  Actual :  time
# predicted :  ,  Actual :  to
# predicted :  ,  Actual :  see
# predicted :  ,  Actual :  it
# predicted :  ,  Actual :  pop
# predicted :  ,  Actual :  down
# predicted :  ,  Actual :  a
# predicted :  ,  Actual :  large
# predicted :  ,  Actual :  rabbit-hole
# predicted :  ,  Actual :  under
# predicted :  ,  Actual :  the
# predicted :  ,  Actual :  hedge
# predicted :  ,  Actual :  .
# predicted :  ,  Actual :  In
# predicted :  ,  Actual :  another
# predicted :  ,  Actual :  moment
# predicted :  ,  Actual :  down
# predicted :  ,  Actual :  went
# predicted :  ,  Actual :  Alice
# predicted :  ,  Actual :  after
# predicted :  ,  Actual :  it
# predicted :  ,  Actual :  ,
# predicted :  ,  Actual :  never
# predicted :  ,  Actual :  once
# predicted :  ,  Actual :  considering
# predicted :  ,  Actual :  how
# predicted :  ,  Actual :  in
# predicted :  ,  Actual :  the
# predicted :  ,  Actual :  world
# predicted :  ,  Actual :  she
# predicted :  ,  Actual :  was
# predicted :  ,  Actual :  to
# predicted :  ,  Actual :  get
# predicted :  ,  Actual :  out
# predicted :  ,  Actual :  again
# predicted :  ,  Actual :  .
# predicted :  ,  Actual :  The
# predicted :  ,  Actual :  rabbit-hole
# predicted :  ,  Actual :  went
# predicted :  ,  Actual :  straight
# predicted :  ,  Actual :  on
# predicted :  ,  Actual :  like
# predicted :  ,  Actual :  a
# predicted :  ,  Actual :  tunnel
# predicted :  ,  Actual :  for
# predicted :  ,  Actual :  some
# predicted :  ,  Actual :  way
# predicted :  ,  Actual :  ,
# predicted :  ,  Actual :  and
# predicted :  ,  Actual :  then
# predicted :  ,  Actual :  dipped
# predicted :  ,  Actual :  suddenly
# predicted :  ,  Actual :  down
# predicted :  ,  Actual :  ,
# predicted :  ,  Actual :  so
# predicted :  ,  Actual :  suddenly
# predicted :  ,  Actual :  that
# predicted :  ,  Actual :  Alice
# predicted :  ,  Actual :  had
# predicted :  ,  Actual :  not
# predicted :  ,  Actual :  a
# predicted :  ,  Actual :  moment
# predicted :  ,  Actual :  to
# predicted :  ,  Actual :  think
# predicted :  ,  Actual :  about
# predicted :  ,  Actual :  stopping
# predicted :  ,  Actual :  herself
# predicted :  ,  Actual :  before
# predicted :  ,  Actual :  she
# predicted :  ,  Actual :  found
# predicted :  ,  Actual :  herself
# predicted :  ,  Actual :  falling
# predicted :  ,  Actual :  down
# predicted :  ,  Actual :  a
# predicted :  ,  Actual :  very
# predicted :  ,  Actual :  deep
# predicted :  ,  Actual :  well
# predicted :  ,  Actual :  .
# predicted :  ,  Actual :  Either
# predicted :  ,  Actual :  the
# predicted :  ,  Actual :  well
# predicted :  ,  Actual :  was
# predicted :  ,  Actual :  very
# predicted :  ,  Actual :  deep
# predicted :  ,  Actual :  ,
# predicted :  ,  Actual :  or
# predicted :  ,  Actual :  she
# predicted :  ,  Actual :  fell
# predicted :  ,  Actual :  very
# predicted :  ,  Actual :  slowly
# predicted :  ,  Actual :  ,
# predicted :  ,  Actual :  for
# predicted :  ,  Actual :  she
# predicted :  ,  Actual :  had
# predicted :  ,  Actual :  plenty
# predicted :  ,  Actual :  of
# predicted :  ,  Actual :  time
# predicted :  ,  Actual :  as
# predicted :  ,  Actual :  she
# predicted :  ,  Actual :  went
# predicted :  ,  Actual :  down
# predicted :  ,  Actual :  to
# predicted :  ,  Actual :  look
# predicted :  ,  Actual :  about
# predicted :  ,  Actual :  her
# predicted :  ,  Actual :  and
# predicted :  ,  Actual :  to
# predicted :  ,  Actual :  wonder
# predicted :  ,  Actual :  what
# predicted :  ,  Actual :  was
# predicted :  ,  Actual :  going
# predicted :  ,  Actual :  to
# predicted :  ,  Actual :  happen
# predicted :  ,  Actual :  next
# predicted :  ,  Actual :  .
# predicted :  ,  Actual :  First
# predicted :  ,  Actual :  ,
# predicted :  ,  Actual :  she
# predicted :  ,  Actual :  tried
# predicted :  ,  Actual :  to
# predicted :  ,  Actual :  look
# predicted :  ,  Actual :  down
# predicted :  ,  Actual :  and
# predicted :  ,  Actual :  make
# predicted :  ,  Actual :  out
# predicted :  ,  Actual :  what
# predicted :  ,  Actual :  she
# predicted :  ,  Actual :  was
# predicted :  ,  Actual :  coming
# predicted :  ,  Actual :  to
# predicted :  ,  Actual :  ,
# predicted :  ,  Actual :  but
# predicted :  ,  Actual :  it
# predicted :  ,  Actual :  was
# predicted :  ,  Actual :  too
# predicted :  ,  Actual :  dark
# predicted :  ,  Actual :  to
# predicted :  ,  Actual :  see
# predicted :  ,  Actual :  anything
# predicted :  ,  Actual :  ;
# predicted :  ,  Actual :  then
# predicted :  ,  Actual :  she
# predicted :  ,  Actual :  looked
# predicted :  ,  Actual :  at
# predicted :  ,  Actual :  the
# predicted :  ,  Actual :  sides
# predicted :  ,  Actual :  of
# predicted :  ,  Actual :  the
# predicted :  ,  Actual :  well
# predicted :  ,  Actual :  ,
# predicted :  ,  Actual :  and
# predicted :  ,  Actual :  noticed
# predicted :  ,  Actual :  that
# predicted :  ,  Actual :  they
# predicted :  ,  Actual :  were
# predicted :  ,  Actual :  filled
# predicted :  ,  Actual :  with
# predicted :  ,  Actual :  cupboards
# predicted :  ,  Actual :  and
# predicted :  ,  Actual :  book-shelves
# predicted :  ,  Actual :  ;
# predicted :  ,  Actual :  here
# predicted :  ,  Actual :  and
# predicted :  ,  Actual :  there
# predicted :  ,  Actual :  she
# predicted :  ,  Actual :  saw
# predicted :  ,  Actual :  maps
# predicted :  ,  Actual :  and
# predicted :  ,  Actual :  pictures
# predicted :  ,  Actual :  hung
# predicted :  ,  Actual :  upon
# predicted :  ,  Actual :  pegs
# predicted :  ,  Actual :  .
# predicted :  ,  Actual :  She
# predicted :  ,  Actual :  took
# predicted :  ,  Actual :  down
# predicted :  ,  Actual :  a
# predicted :  ,  Actual :  jar
# predicted :  ,  Actual :  from
# predicted :  ,  Actual :  one
# predicted :  ,  Actual :  of
# predicted :  ,  Actual :  the
# predicted :  ,  Actual :  shelves
# predicted :  ,  Actual :  as
# predicted :  ,  Actual :  she
# predicted :  ,  Actual :  passed
# predicted :  ,  Actual :  ;
# predicted :  ,  Actual :  it
# predicted :  ,  Actual :  was
# predicted :  ,  Actual :  labelled
# predicted :  ,  Actual :  ‘
# predicted :  ,  Actual :  ORANGE
# predicted :  ,  Actual :  MARMALADE
# predicted :  ,  Actual :  ’
# predicted :  ,  Actual :  ,
# predicted :  ,  Actual :  but
# predicted :  ,  Actual :  to
# predicted :  ,  Actual :  her
# predicted :  ,  Actual :  great
# predicted :  ,  Actual :  disappointment
# predicted :  ,  Actual :  it
# predicted :  ,  Actual :  was
# predicted :  ,  Actual :  empty
# predicted :  ,  Actual :  :
# predicted :  ,  Actual :  she
# predicted :  ,  Actual :  did
# predicted :  ,  Actual :  not
# predicted :  ,  Actual :  like
# predicted :  ,  Actual :  to
# predicted :  ,  Actual :  drop
# predicted :  ,  Actual :  the
# predicted :  ,  Actual :  jar
# predicted :  ,  Actual :  for
# predicted :  ,  Actual :  fear
# predicted :  ,  Actual :  of
# predicted :  ,  Actual :  killing
# predicted :  ,  Actual :  somebody
# predicted :  ,  Actual :  ,
# predicted :  ,  Actual :  so
# predicted :  ,  Actual :  managed
# predicted :  ,  Actual :  to
# predicted :  ,  Actual :  put
# predicted :  ,  Actual :  it
# predicted :  ,  Actual :  into
# predicted :  ,  Actual :  one
# predicted :  ,  Actual :  of
# predicted :  ,  Actual :  the
# predicted :  ,  Actual :  cupboards
# predicted :  ,  Actual :  as
# predicted :  ,  Actual :  she
# predicted :  ,  Actual :  fell
# predicted :  ,  Actual :  past
# predicted :  ,  Actual :  it
# predicted :  ,  Actual :  .
# predicted :  ,  Actual :  ‘
# predicted :  ,  Actual :  Well
# predicted :  ,  Actual :  !
# predicted :  ,  Actual :  ’
# predicted :  ,  Actual :  thought
# predicted :  ,  Actual :  Alice
# predicted :  ,  Actual :  to
# predicted :  ,  Actual :  herself
# predicted :  ,  Actual :  ,
# predicted :  ,  Actual :  ‘
# predicted :  ,  Actual :  after
# predicted :  ,  Actual :  such
# predicted :  ,  Actual :  a
# predicted :  ,  Actual :  fall
# predicted :  ,  Actual :  as
# predicted :  ,  Actual :  this
# predicted :  ,  Actual :  ,
# predicted :  ,  Actual :  I
# predicted :  ,  Actual :  shall
# predicted :  ,  Actual :  think
# predicted :  ,  Actual :  nothing
# predicted :  ,  Actual :  of
# predicted :  ,  Actual :  tumbling
# predicted :  ,  Actual :  down
# predicted :  ,  Actual :  stairs
# predicted :  ,  Actual :  !
# predicted :  ,  Actual :  How
# predicted :  ,  Actual :  brave
# predicted :  ,  Actual :  they
# predicted :  ,  Actual :  ’
# predicted :  ,  Actual :  ll
# predicted :  ,  Actual :  all
# predicted :  ,  Actual :  think
# predicted :  ,  Actual :  me
# predicted :  ,  Actual :  at
# predicted :  ,  Actual :  home
# predicted :  ,  Actual :  !
# predicted :  ,  Actual :  Why
# predicted :  ,  Actual :  ,
# predicted :  ,  Actual :  I
# predicted :  ,  Actual :  wouldn
# predicted :  ,  Actual :  ’
# predicted :  ,  Actual :  t
# predicted :  ,  Actual :  say
# predicted :  ,  Actual :  anything
# predicted :  ,  Actual :  about
# predicted :  ,  Actual :  it
# predicted :  ,  Actual :  ,
# predicted :  ,  Actual :  even
# predicted :  ,  Actual :  if
# predicted :  ,  Actual :  I
# predicted :  ,  Actual :  fell
# predicted :  ,  Actual :  off
# predicted :  ,  Actual :  the
# predicted :  ,  Actual :  top
# predicted :  ,  Actual :  of
# predicted :  ,  Actual :  the
# predicted :  ,  Actual :  house
# predicted :  ,  Actual :  !
# predicted :  ,  Actual :  ’
# predicted :  ,  Actual :  (
# predicted :  ,  Actual :  Which
# predicted :  ,  Actual :  was
# predicted :  ,  Actual :  very
# predicted :  ,  Actual :  likely
# predicted :  ,  Actual :  true
# predicted :  ,  Actual :  .
# predicted :  ,  Actual :  )
# predicted :  ,  Actual :  Down
# predicted :  ,  Actual :  ,
# predicted :  ,  Actual :  down
# predicted :  ,  Actual :  ,
# predicted :  ,  Actual :  down
# predicted :  ,  Actual :  .
# predicted :  ,  Actual :  Would
# predicted :  ,  Actual :  the
# predicted :  ,  Actual :  fall
# predicted :  ,  Actual :  NEVER
# predicted :  ,  Actual :  come
# predicted :  ,  Actual :  to
# predicted :  ,  Actual :  an
# predicted :  ,  Actual :  end
# predicted :  ,  Actual :  !
# predicted :  ,  Actual :  ‘
# predicted :  ,  Actual :  I
# predicted :  ,  Actual :  wonder
# predicted :  ,  Actual :  how
# predicted :  ,  Actual :  many
# predicted :  ,  Actual :  miles
# predicted :  ,  Actual :  I
# predicted :  ,  Actual :  ’
# predicted :  ,  Actual :  ve
# predicted :  ,  Actual :  fallen
# predicted :  ,  Actual :  by
# predicted :  ,  Actual :  this
# predicted :  ,  Actual :  time
# predicted :  ,  Actual :  ?
# predicted :  ,  Actual :  ’
# predicted :  ,  Actual :  she
# predicted :  ,  Actual :  said
# predicted :  ,  Actual :  aloud
# predicted :  ,  Actual :  .
# predicted :  ,  Actual :  ‘
# predicted :  ,  Actual :  I
# predicted :  ,  Actual :  must
# predicted :  ,  Actual :  be
# predicted :  ,  Actual :  getting
# predicted :  ,  Actual :  somewhere
# predicted :  ,  Actual :  near
# predicted :  ,  Actual :  the
# predicted :  ,  Actual :  centre
# predicted :  ,  Actual :  of
# predicted :  ,  Actual :  the
# predicted :  ,  Actual :  earth
# predicted :  ,  Actual :  .
# predicted :  ,  Actual :  Let
# predicted :  ,  Actual :  me
# predicted :  ,  Actual :  see
# predicted :  ,  Actual :  :
# predicted :  ,  Actual :  that
# predicted :  ,  Actual :  would
# predicted :  ,  Actual :  be
# predicted :  ,  Actual :  four
# predicted :  ,  Actual :  thousand
# predicted :  ,  Actual :  miles
# predicted :  ,  Actual :  down
# predicted :  ,  Actual :  ,
# predicted :  ,  Actual :  I
# predicted :  ,  Actual :  think
# predicted :  ,  Actual :  --
# predicted :  ,  Actual :  ’
# predicted :  ,  Actual :  (
# predicted :  ,  Actual :  for
# predicted :  ,  Actual :  ,
# predicted :  ,  Actual :  you
# predicted :  ,  Actual :  see
# predicted :  ,  Actual :  ,
# predicted :  ,  Actual :  Alice
# predicted :  ,  Actual :  had
# predicted :  ,  Actual :  learnt
# predicted :  ,  Actual :  several
# predicted :  ,  Actual :  things
# predicted :  ,  Actual :  of
# predicted :  ,  Actual :  this
# predicted :  ,  Actual :  sort
# predicted :  ,  Actual :  in
# predicted :  ,  Actual :  her
# predicted :  ,  Actual :  lessons
# predicted :  ,  Actual :  in
# predicted :  ,  Actual :  the
# predicted :  ,  Actual :  schoolroom
# predicted :  ,  Actual :  ,
# predicted :  ,  Actual :  and
# predicted :  ,  Actual :  though
# predicted :  ,  Actual :  this
# predicted :  ,  Actual :  was
# predicted :  ,  Actual :  not
# predicted :  ,  Actual :  a
# predicted :  ,  Actual :  VERY
# predicted :  ,  Actual :  good
# predicted :  ,  Actual :  opportunity
# predicted :  ,  Actual :  for
# predicted :  ,  Actual :  showing
# predicted :  ,  Actual :  off
# predicted :  ,  Actual :  her
# predicted :  ,  Actual :  knowledge
# predicted :  ,  Actual :  ,
# predicted :  ,  Actual :  as
# predicted :  ,  Actual :  there
# predicted :  ,  Actual :  was
# predicted :  ,  Actual :  no
# predicted :  ,  Actual :  one
# predicted :  ,  Actual :  to
# predicted :  ,  Actual :  listen
# predicted :  ,  Actual :  to
# predicted :  ,  Actual :  her
# predicted :  ,  Actual :  ,
# predicted :  ,  Actual :  still
# predicted :  ,  Actual :  it
# predicted :  ,  Actual :  was
# predicted :  ,  Actual :  good
# predicted :  ,  Actual :  practice
# predicted :  ,  Actual :  to
# predicted :  ,  Actual :  say
# predicted :  ,  Actual :  it
# predicted :  ,  Actual :  over
# predicted :  ,  Actual :  )
# predicted :  ,  Actual :  ‘
# predicted :  ,  Actual :  --
# predicted :  ,  Actual :  yes
# predicted :  ,  Actual :  ,
# predicted :  ,  Actual :  that
# predicted :  ,  Actual :  ’
# predicted :  ,  Actual :  s
# predicted :  ,  Actual :  about
# predicted :  ,  Actual :  the
# predicted :  ,  Actual :  right
# predicted :  ,  Actual :  distance
# predicted :  ,  Actual :  --
# predicted :  ,  Actual :  but
# predicted :  ,  Actual :  then
# predicted :  ,  Actual :  I
# predicted :  ,  Actual :  wonder
# predicted :  ,  Actual :  what
# predicted :  ,  Actual :  Latitude
# predicted :  ,  Actual :  or
# predicted :  ,  Actual :  Longitude
# predicted :  ,  Actual :  I
# predicted :  ,  Actual :  ’
# predicted :  ,  Actual :  ve
# predicted :  ,  Actual :  got
# predicted :  ,  Actual :  to
# predicted :  ,  Actual :  ?
# predicted :  ,  Actual :  ’
# predicted :  ,  Actual :  (
# predicted :  ,  Actual :  Alice
# predicted :  ,  Actual :  had
# predicted :  ,  Actual :  no
# predicted :  ,  Actual :  idea
# predicted :  ,  Actual :  what
# predicted :  ,  Actual :  Latitude
# predicted :  ,  Actual :  was
# predicted :  ,  Actual :  ,
# predicted :  ,  Actual :  or
# predicted :  ,  Actual :  Longitude
# predicted :  ,  Actual :  either
# predicted :  ,  Actual :  ,
# predicted :  ,  Actual :  but
# predicted :  ,  Actual :  thought
# predicted :  ,  Actual :  they
# predicted :  ,  Actual :  were
# predicted :  ,  Actual :  nice
# predicted :  ,  Actual :  grand
# predicted :  ,  Actual :  words
# predicted :  ,  Actual :  to
# predicted :  ,  Actual :  say
# predicted :  ,  Actual :  .
# predicted :  ,  Actual :  )
# predicted :  ,  Actual :  Presently
# predicted :  ,  Actual :  she
# predicted :  ,  Actual :  began
# predicted :  ,  Actual :  again
# predicted :  ,  Actual :  .
# predicted :  ,  Actual :  ‘
# predicted :  ,  Actual :  I
# predicted :  ,  Actual :  wonder
# predicted :  ,  Actual :  if
# predicted :  ,  Actual :  I
# predicted :  ,  Actual :  shall
# predicted :  ,  Actual :  fall
# predicted :  ,  Actual :  right
# predicted :  ,  Actual :  THROUGH
# predicted :  ,  Actual :  the
# predicted :  ,  Actual :  earth
# predicted :  ,  Actual :  !
# predicted :  ,  Actual :  How
# predicted :  ,  Actual :  funny
# predicted :  ,  Actual :  it
# predicted :  ,  Actual :  ’
# predicted :  ,  Actual :  ll
# predicted :  ,  Actual :  seem
# predicted :  ,  Actual :  to
# predicted :  ,  Actual :  come
# predicted :  ,  Actual :  out
# predicted :  ,  Actual :  among
# predicted :  ,  Actual :  the
# predicted :  ,  Actual :  people
# predicted :  ,  Actual :  that
# predicted :  ,  Actual :  walk
# predicted :  ,  Actual :  with
# predicted :  ,  Actual :  their
# predicted :  ,  Actual :  heads
# predicted :  ,  Actual :  downward
# predicted :  ,  Actual :  !
# predicted :  ,  Actual :  The
# predicted :  ,  Actual :  Antipathies
# predicted :  ,  Actual :  ,
# predicted :  ,  Actual :  I
# predicted :  ,  Actual :  think
# predicted :  ,  Actual :  --
# predicted :  ,  Actual :  ’
# predicted :  ,  Actual :  (
# predicted :  ,  Actual :  she
# predicted :  ,  Actual :  was
# predicted :  ,  Actual :  rather
# predicted :  ,  Actual :  glad
# predicted :  ,  Actual :  there
# predicted :  ,  Actual :  WAS
# predicted :  ,  Actual :  no
# predicted :  ,  Actual :  one
# predicted :  ,  Actual :  listening
# predicted :  ,  Actual :  ,
# predicted :  ,  Actual :  this
# predicted :  ,  Actual :  time
# predicted :  ,  Actual :  ,
# predicted :  ,  Actual :  as
# predicted :  ,  Actual :  it
# predicted :  ,  Actual :  didn
# predicted :  ,  Actual :  ’
# predicted :  ,  Actual :  t
# predicted :  ,  Actual :  sound
# predicted :  ,  Actual :  at
# predicted :  ,  Actual :  all
# predicted :  ,  Actual :  the
# predicted :  ,  Actual :  right
# predicted :  ,  Actual :  word
# predicted :  ,  Actual :  )
# predicted :  ,  Actual :  ‘
# predicted :  ,  Actual :  --
# predicted :  ,  Actual :  but
# predicted :  ,  Actual :  I
# predicted :  ,  Actual :  shall
# predicted :  ,  Actual :  have
# predicted :  ,  Actual :  to
# predicted :  ,  Actual :  ask
# predicted :  ,  Actual :  them
# predicted :  ,  Actual :  what
# predicted :  ,  Actual :  the
# predicted :  ,  Actual :  name
# predicted :  ,  Actual :  of
# predicted :  ,  Actual :  the
# predicted :  ,  Actual :  country
# predicted :  ,  Actual :  is
# predicted :  ,  Actual :  ,
# predicted :  ,  Actual :  you
# predicted :  ,  Actual :  know
# predicted :  ,  Actual :  .
# predicted :  ,  Actual :  Please
# predicted :  ,  Actual :  ,
# predicted :  ,  Actual :  Ma
# predicted :  ,  Actual :  ’
# predicted :  ,  Actual :  am
# predicted :  ,  Actual :  ,
# predicted :  ,  Actual :  is
# predicted :  ,  Actual :  this
# predicted :  ,  Actual :  New
# predicted :  ,  Actual :  Zealand
# predicted :  ,  Actual :  or
# predicted :  ,  Actual :  Australia
# predicted :  ,  Actual :  ?
# predicted :  ,  Actual :  ’
# predicted :  ,  Actual :  (
# predicted :  ,  Actual :  and
# predicted :  ,  Actual :  she
# predicted :  ,  Actual :  tried
# predicted :  ,  Actual :  to
# predicted :  ,  Actual :  curtsey
# predicted :  ,  Actual :  as
# predicted :  ,  Actual :  she
# predicted :  ,  Actual :  spoke
# predicted :  ,  Actual :  --
# predicted :  ,  Actual :  fancy
# predicted :  ,  Actual :  CURTSEYING
# predicted :  ,  Actual :  as
# predicted :  ,  Actual :  you
# predicted :  ,  Actual :  ’
# predicted :  ,  Actual :  re
# predicted :  ,  Actual :  falling
# predicted :  ,  Actual :  through
# predicted :  ,  Actual :  the
# predicted :  ,  Actual :  air
# predicted :  ,  Actual :  !
# predicted :  ,  Actual :  Do
# predicted :  ,  Actual :  you
# predicted :  ,  Actual :  think
# predicted :  ,  Actual :  you
# predicted :  ,  Actual :  could
# predicted :  ,  Actual :  manage
# predicted :  ,  Actual :  it
# predicted :  ,  Actual :  ?
# predicted :  ,  Actual :  )
# predicted :  ,  Actual :  ‘
# predicted :  ,  Actual :  And
# predicted :  ,  Actual :  what
# predicted :  ,  Actual :  an
# predicted :  ,  Actual :  ignorant
# predicted :  ,  Actual :  little
# predicted :  ,  Actual :  girl
# predicted :  ,  Actual :  she
# predicted :  ,  Actual :  ’
# predicted :  ,  Actual :  ll
# predicted :  ,  Actual :  think
# predicted :  ,  Actual :  me
# predicted :  ,  Actual :  for
# predicted :  ,  Actual :  asking
# predicted :  ,  Actual :  !
# predicted :  ,  Actual :  No
# predicted :  ,  Actual :  ,
# predicted :  ,  Actual :  it
# predicted :  ,  Actual :  ’
# predicted :  ,  Actual :  ll
# predicted :  ,  Actual :  never
# predicted :  ,  Actual :  do
# predicted :  ,  Actual :  to
# predicted :  ,  Actual :  ask
# predicted :  ,  Actual :  :
# predicted :  ,  Actual :  perhaps
# predicted :  ,  Actual :  I
# predicted :  ,  Actual :  shall
# predicted :  ,  Actual :  see
# predicted :  ,  Actual :  it
# predicted :  ,  Actual :  written
# predicted :  ,  Actual :  up
# predicted :  ,  Actual :  somewhere.
# predicted :  ,  Actual :  ’
# predicted :  ,  Actual :  Down
# predicted :  ,  Actual :  ,
# predicted :  ,  Actual :  down
# predicted :  ,  Actual :  ,
# predicted :  ,  Actual :  down
# predicted :  ,  Actual :  .
# predicted :  ,  Actual :  There
# predicted :  ,  Actual :  was
# predicted :  ,  Actual :  nothing
# predicted :  ,  Actual :  else
# predicted :  ,  Actual :  to
# predicted :  ,  Actual :  do
# predicted :  ,  Actual :  ,
# predicted :  ,  Actual :  so
# predicted :  ,  Actual :  Alice
# predicted :  ,  Actual :  soon
# predicted :  ,  Actual :  began
# predicted :  ,  Actual :  talking
# predicted :  ,  Actual :  again
# predicted :  ,  Actual :  .
# predicted :  ,  Actual :  ‘
# predicted :  ,  Actual :  Dinah
# predicted :  ,  Actual :  ’
# predicted :  ,  Actual :  ll
# predicted :  ,  Actual :  miss
# predicted :  ,  Actual :  me
# predicted :  ,  Actual :  very
# predicted :  ,  Actual :  much
# predicted :  ,  Actual :  to-night
# predicted :  ,  Actual :  ,
# predicted :  ,  Actual :  I
# predicted :  ,  Actual :  should
# predicted :  ,  Actual :  think
# predicted :  ,  Actual :  !
# predicted :  ,  Actual :  ’
# predicted :  ,  Actual :  (
# predicted :  ,  Actual :  Dinah
# predicted :  ,  Actual :  was
# predicted :  ,  Actual :  the
# predicted :  ,  Actual :  cat
# predicted :  ,  Actual :  .
# predicted :  ,  Actual :  )
# predicted :  ,  Actual :  ‘
# predicted :  ,  Actual :  I
# predicted :  ,  Actual :  hope
# predicted :  ,  Actual :  they
# predicted :  ,  Actual :  ’
# predicted :  ,  Actual :  ll
# predicted :  ,  Actual :  remember
# predicted :  ,  Actual :  her
# predicted :  ,  Actual :  saucer
# predicted :  ,  Actual :  of
# predicted :  ,  Actual :  milk
# predicted :  ,  Actual :  at
# predicted :  ,  Actual :  tea-time
# predicted :  ,  Actual :  .
# predicted :  ,  Actual :  Dinah
# predicted :  ,  Actual :  my
# predicted :  ,  Actual :  dear
# predicted :  ,  Actual :  !
# predicted :  ,  Actual :  I
# predicted :  ,  Actual :  wish
